# %% [markdown]
# # Assignment 1 - histogram

# %%
#import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib

# # Look pretty...
# # matplotlib.style.use('ggplot')
# plt.style.use('ggplot')

# student_dataset = pd.read_csv("/Datasets/students.data", index_col=0)

# my_series = student_dataset.G3
# my_dataframe = student_dataset[['G3', 'G2', 'G1']] 

# my_series.plot.hist(alpha=0.5)
# my_dataframe.plot.hist(alpha=0.5)

# df = pd.read_csv('/home/chris/Documents/python_course/Module3/Datasets/wheat.data')

# df1 = df.iloc[:,[1,2]]

# df2 = df.iloc[:,[7,6]]

#print df1

#print df2

#df

# df1.plot.hist(alpha=0.5)

# df2.plot.hist(alpha=0.75)

# plt.show()

# %% [markdown]
# # Assignment 2 - 2d scatter plots

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib

# # Look pretty...
# matplotlib.style.use('ggplot')
# plt.style.use('ggplot')

# df = pd.read_csv('/home/chris/Documents/python_course/Module3/Datasets/wheat.data')

# df1 = df.iloc[:,[1,2]]

# df2 = df.iloc[:,[7,6]]

# df3 = df.iloc[:,[3,5]]

# df1.plot.scatter(x='area', y='perimeter')

# df2.plot.scatter(x='groove', y='asymmetry')

# df3.plot.scatter(x='compactness', y='width')



# plt.show()

# %% [markdown]
# # Assignment 3 - 3d scatter plots

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib
# from mpl_toolkits.mplot3d import Axes3D

# # Look pretty...
# matplotlib.style.use('ggplot')
# plt.style.use('ggplot')

# df = pd.read_csv('/home/chris/Documents/python_course/Module3/Datasets/wheat.data')

# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.set_xlabel('area')
# ax.set_ylabel('perimeter')
# ax.set_zlabel('asymmetry')

# ax.scatter(df.area, df.perimeter, df.asymmetry, c='r', marker='.')

# fig2 = plt.figure()
# ax2 = fig2.add_subplot(111, projection='3d')
# ax2.set_xlabel('width')
# ax.set_ylabel('groove')
# ax.set_zlabel('length')

# ax2.scatter(df.width, df.groove, df.length, c='g', marker='.')

# plt.show()

# %% [markdown]
# # Assignment 4 - parallel coordinates

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib

# from pandas.tools.plotting import parallel_coordinates

# # Look pretty...
# # matplotlib.style.use('ggplot')
# plt.style.use('ggplot')

# df = pd.read_csv('/home/chris/Documents/python_course/Module3/Datasets/wheat.data') 
# df = df.drop(labels=['id', 'area', 'perimeter'], axis=1)

# df

# #df['target_names'] = [data.target_names[i] for i in data.target]

# # Parallel Coordinates Start Here:
# plt.figure()
# parallel_coordinates(df, 'wheat_type')
# plt.show()

# %% [markdown]
# # Assignment 5 - Andrew's curves

# %%
# from pandas.tools.plotting import andrews_curves

# import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib

# # Look pretty...
# matplotlib.style.use('ggplot')
# # If the above line throws an error, use plt.style.use('ggplot') instead

# df = pd.read_csv('/home/chris/Documents/python_course/Module3/Datasets/wheat.data') 
# # df = df.drop(labels=['id', 'area', 'perimeter'], axis=1)
# df = df.drop(labels=['id'], axis=1)

# # Andrews Curves Start Here:
# plt.figure()
# andrews_curves(df, 'wheat_type')
# plt.show()

# %% [markdown]
# # Assignment 6 - imshow

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib

# # Look pretty...
# matplotlib.style.use('ggplot')
# # If the above line throws an error, use plt.style.use('ggplot') instead

# df = pd.read_csv('/home/chris/Documents/python_course/Module3/Datasets/wheat.data') 
# # # df = df.drop(labels=['id', 'area', 'perimeter'], axis=1)
# df = df.drop(labels=['id'], axis=1)

# print df.corr()

# plt.imshow(df.corr(), cmap=plt.cm.Blues, interpolation='nearest')
# plt.colorbar()
# tick_marks = [i for i in range(len(df.columns))]
# plt.xticks(tick_marks, df.columns, rotation='vertical')
# plt.yticks(tick_marks, df.columns)

# plt.show()
