# %% [markdown]
# # Assignment 1 - wasn't a coding task so no output here

# %% [markdown]
# # Assignment 2

# %%
# import pandas as pd

# df = pd.read_csv('/home/chris/Documents/python_course/Module2/Datasets/tutorial.csv')

# df

# df.loc[2:4, 'col3']

# %% [markdown]
# # Assignment 3 - part 1

# %%
# import pandas as pd

# df = pd.read_csv('/home/chris/Documents/python_course/Module2/Datasets/servo.data')

# i = df[df.vgain==5]

# i.shape

# %% [markdown]
# # Assignment 3 - part 2

# %%
# import pandas as pd

# df = pd.read_csv('/home/chris/Documents/python_course/Module2/Datasets/servo.data')

# df[(df.motor=='E') & (df.screw=='E')]

# %% [markdown]
# # Assignment 3 - part 3

# %%
# import pandas as pd

# df = pd.read_csv('/home/chris/Documents/python_course/Module2/Datasets/servo.data')

# i = df[df.pgain==4]

# i.vgain.mean()

# %% [markdown]
# # Assignment 4 - parts 1, 2, 3 & 4

# %%
# import pandas as pd

# df = pd.read_html('http://www.espn.com/nhl/statistics/player/_/stat/points/sort/points/year/2015/seasontype/2', skiprows=(1, 13, 25, 37))

# df[0].columns = ['RK','Player','Team','GP','G','A','PTS','+/-','PIM','PTS/G','SOG','PCT','GWG','G','A','G','A']

# df = df[0].drop(labels=['RK'], axis=1)

# df = df.dropna(axis=0, thresh=4)

# df = df.reset_index(drop=True)

# df

# #df.dtypes

# %% [markdown]
# # Assignment 5 - parts 1, 2 & 3

# %%
# import pandas as pd
# import numpy as np

# df = pd.read_csv('/home/chris/Documents/python_course/Module2/Datasets/census.data', index_col=0)

# df.columns = ['education', 'age', 'capitalGain', 'race', 'capital-loss', 'hours-per-week', 'sex', 'classification']

# df.capitalGain = pd.to_numeric(df.capitalGain, errors='coerce')
# df.fillna(-1)

# df = pd.get_dummies(df,columns=['education'])

# df = pd.get_dummies(df,columns=['classification'])

# df
