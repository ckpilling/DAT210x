# %% [markdown]
# # Assignment 3 - part 2

# %%
import pandas as pd
from datetime import timedelta
import matplotlib.pyplot as plt
import matplotlib
import time
from sklearn.cluster import KMeans
matplotlib.style.use('ggplot') # Look Pretty

def showandtell(title=None):
  if title != None: plt.savefig(title + str(time.time()) + ".png", bbox_inches='tight', dpi=300)
  plt.show()

def clusterInfo(model):
  print "Cluster Analysis Inertia: ", model.inertia_
  print '------------------------------------------'
  for p in range(len(model.cluster_centers_)):
    print "\n  Cluster ", p
    print "    Centroid ", model.cluster_centers_[p]
    print "    #Samples ", (model.labels_==p).sum() # NumPy Power
    
# Find the cluster with the least # attached nodes
def clusterWithFewestSamples(model):
  # Ensure there's at least on cluster...
  minSamples = len(model.labels_)
  minCluster = 0
  for i in range(len(model.cluster_centers_)):
    if minSamples > (model.labels_==i).sum():
      minCluster = i
      minSamples = (model.labels_==i).sum()
  print "\n  Cluster With Fewest Samples: ", minCluster
  return (model.labels_==minCluster)

# Find the cluster with the most # attached nodes
def clusterWithMostSamples(model):
  # Ensure there's at least on cluster...
  maxSamples = len(model.labels_)
  maxCluster = 0
  for i in range(len(model.cluster_centers_)):    
    if maxSamples < (model.labels_==i).sum():
      maxCluster = i
      maxSamples = (model.labels_==i).sum()
  print "\n  Cluster With Most Samples: ", maxCluster
  return (model.labels_==maxCluster)

def doKMeans(data, clusters=0):
    # Plot your data with a '.' marker, with 0.3 alpha at the Longitude and Latitude locations
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.scatter(user1.TowerLon, user1.TowerLat, marker='.', c='gray', alpha=0.3)

    #Filter df on Longitude and Latitude,
    df2 = user1[['TowerLon','TowerLat']]

    # Use K-Means to find seven cluster centers.
    model = KMeans(n_clusters=clusters)
    model.fit(df2)
    KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=7, n_init=10,n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,verbose=0)

    labels = model.predict(df2)
    centroids = model.cluster_centers_

    #Print and plot the centroids...
    centroids = model.cluster_centers_
    ax.scatter(centroids[:,0], centroids[:,1], marker='X', c='yellow', alpha=0.5, linewidths=10, s=169)
    print centroids
    return model

# Load the dataset convert the date to datetime, and the time to timedelta

df = pd.read_csv('/home/chris/Documents/python_course/Module5/Datasets/CDR.csv')

df['CallDate'] = pd.to_datetime(df['CallDate'])
df['CallTime'] = pd.to_timedelta(df['CallTime'])

#print 'The order of the numbers in the df is ', df.In.unique()

# Create a list of the unique phone-number values

unique_numbers = df.In.unique()
#print 'The order of the numbers in the edited df is', unique_numbers

a = unique_numbers

index = 0
for row in range(len(a)):
    b = (row)
    user1 = df[df.In == a[(row)]]
    print '------------------------------------------------------------------------------------'
    print 'phone number', b, '=', a[row]
    print "\n\nExamining person: ", b

    # Edit slice so that it includes only Weekday (Mon-Fri) values.
    user1 = user1[(user1.DOW !='Sat') & (user1.DOW !='Sun')]
    #print user1.shape

    user1 = user1[(user1.CallTime > '07:30:00') & (user1.CallTime < '17:00:00')]
    #print 'user1 shape for weekday calls is', user1.shape
    #print unique_numbers[0]

    # Plot the Cell Towers users connected to
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.scatter(user1.TowerLon,user1.TowerLat, c='g', marker='o', alpha=0.2)
    ax.set_title('Weekday calls between 07:00 & 17:00')
    plt.show()

    # Run K-Means
    model = doKMeans(user1, 4)

    midWayClusterIndices = clusterWithFewestSamples(model)
    maxWayClusterIndices = clusterWithMostSamples(model)
    midWaySamples = user1[midWayClusterIndices]
    print "    Its Waypoint Time: ", midWaySamples.CallTime.mean()
    
    maxClusterIndices = clusterInfo(model)
    print maxClusterIndices

    # visualise results
    ax.scatter(model.cluster_centers_[:,1], model.cluster_centers_[:,0], s=169, c='yellow', marker='X', alpha=0.8, linewidths=2)
    # save results to a .png
    #showandtell('Weekday Calls Centroids')  # Comment out if not desired.
    
    ##### THE END!
# Out:
# ------------------------------------------------------------------------------------
# phone number 0 = 4638472273
#
#
# Examining person:  0
# [[-96.91021922  32.89967733]
#  [-96.81945506  32.84577996]
#  [-96.85151976  32.87385429]
#  [-96.892222    32.911583  ]]
#
#   Cluster With Fewest Samples:  3
#
#   Cluster With Most Samples:  0
#     Its Waypoint Time:  0 days 07:44:40.628124
# Cluster Analysis Inertia:  0.0546895620982
# ------------------------------------------
#
#   Cluster  0
#     Centroid  [-96.91021922  32.89967733]
#     #Samples  916
#
#   Cluster  1
#     Centroid  [-96.81945506  32.84577996]
#     #Samples  52
#
#   Cluster  2
#     Centroid  [-96.85151976  32.87385429]
#     #Samples  94
#
#   Cluster  3
#     Centroid  [-96.892222  32.911583]
#     #Samples  36
# These are maxClusterIndices None
# ------------------------------------------------------------------------------------
# phone number 1 = 1559410755
#
#
# Examining person:  1
# [[-96.93522566  32.6963351 ]
#  [-96.91638911  32.7674977 ]
#  [-96.91649315  32.72173631]
#  [-96.93478615  32.67082197]]
#
#   Cluster With Fewest Samples:  3
#
#   Cluster With Most Samples:  0
#     Its Waypoint Time:  0 days 08:22:21.479006
# Cluster Analysis Inertia:  0.0341313210665
# ------------------------------------------
#
#   Cluster  0
#     Centroid  [-96.93522566  32.6963351 ]
#     #Samples  3026
#
#   Cluster  1
#     Centroid  [-96.91638911  32.7674977 ]
#     #Samples  122
#
#   Cluster  2
#     Centroid  [-96.91649315  32.72173631]
#     #Samples  235
#
#   Cluster  3
#     Centroid  [-96.93478615  32.67082197]
#     #Samples  87
# These are maxClusterIndices None
# ------------------------------------------------------------------------------------
# phone number 2 = 4931532174
#
#
# Examining person:  2
# [[-96.893333    32.780278  ]
#  [-96.893917    32.81075   ]
#  [-96.900417    32.74356483]
#  [-96.88104548  32.81738606]]
#
#   Cluster With Fewest Samples:  2
#
#   Cluster With Most Samples:  0
#     Its Waypoint Time:  0 days 11:18:57.882944
# Cluster Analysis Inertia:  0.00231002792644
# ------------------------------------------
#
#   Cluster  0
#     Centroid  [-96.893333  32.780278]
#     #Samples  836
#
#   Cluster  1
#     Centroid  [-96.893917  32.81075 ]
#     #Samples  56
#
#   Cluster  2
#     Centroid  [-96.900417    32.74356483]
#     #Samples  6
#
#   Cluster  3
#     Centroid  [-96.88104548  32.81738606]
#     #Samples  31
# These are maxClusterIndices None
# ------------------------------------------------------------------------------------
# phone number 3 = 2419930464
#
#
# Examining person:  3
# [[-96.84728933  32.8537123 ]
#  [-96.852389    32.861222  ]
#  [-96.836       32.846722  ]
#  [-96.844722    32.865833  ]]
#
#   Cluster With Fewest Samples:  3
#
#   Cluster With Most Samples:  0
#     Its Waypoint Time:  0 days 10:13:54.377076
# Cluster Analysis Inertia:  6.70741917013e-06
# ------------------------------------------
#
#   Cluster  0
#     Centroid  [-96.84728933  32.8537123 ]
#     #Samples  699
#
#   Cluster  1
#     Centroid  [-96.852389  32.861222]
#     #Samples  21
#
#   Cluster  2
#     Centroid  [-96.836     32.846722]
#     #Samples  17
#
#   Cluster  3
#     Centroid  [-96.844722  32.865833]
#     #Samples  12
# These are maxClusterIndices None
# ------------------------------------------------------------------------------------
# phone number 4 = 1884182865
#
#
# Examining person:  4
# [[-96.75715448  32.92276773]
#  [-96.741944    32.909167  ]
#  [-96.76024108  32.91727969]
#  [-96.800722    32.950861  ]]
#
#   Cluster With Fewest Samples:  3
#
#   Cluster With Most Samples:  0
#     Its Waypoint Time:  0 days 08:08:18.436173
# Cluster Analysis Inertia:  0.000632121181676
# ------------------------------------------
#
#   Cluster  0
#     Centroid  [-96.75715448  32.92276773]
#     #Samples  698
#
#   Cluster  1
#     Centroid  [-96.741944  32.909167]
#     #Samples  65
#
#   Cluster  2
#     Centroid  [-96.76024108  32.91727969]
#     #Samples  127
#
#   Cluster  3
#     Centroid  [-96.800722  32.950861]
#     #Samples  1
# These are maxClusterIndices None
# ------------------------------------------------------------------------------------
# phone number 5 = 3688089071
#
#
# Examining person:  5
# [[-96.87023018  32.81185528]
#  [-96.81309025  32.80082192]
#  [-96.83544438  32.80733155]
#  [-96.78887023  32.79779959]]
#
#   Cluster With Fewest Samples:  3
#
#   Cluster With Most Samples:  0
#     Its Waypoint Time:  0 days 07:43:41.473643
# Cluster Analysis Inertia:  0.0117651252994
# ------------------------------------------
#
#   Cluster  0
#     Centroid  [-96.87023018  32.81185528]
#     #Samples  455
#
#   Cluster  1
#     Centroid  [-96.81309025  32.80082192]
#     #Samples  24
#
#   Cluster  2
#     Centroid  [-96.83544438  32.80733155]
#     #Samples  29
#
#   Cluster  3
#     Centroid  [-96.78887023  32.79779959]
#     #Samples  22
# These are maxClusterIndices None
# ------------------------------------------------------------------------------------
# phone number 6 = 4555003213
#
#
# Examining person:  6
# [[-96.796111    32.7375    ]
#  [-96.742528    32.7535    ]
#  [-96.759167    32.739722  ]
#  [-96.729759    32.77614833]]
#
#   Cluster With Fewest Samples:  3
#
#   Cluster With Most Samples:  0
#     Its Waypoint Time:  0 days 10:48:27.750521
# Cluster Analysis Inertia:  0.000197238304667
# ------------------------------------------
#
#   Cluster  0
#     Centroid  [-96.796111  32.7375  ]
#     #Samples  52
#
#   Cluster  1
#     Centroid  [-96.742528  32.7535  ]
#     #Samples  621
#
#   Cluster  2
#     Centroid  [-96.759167  32.739722]
#     #Samples  81
#
#   Cluster  3
#     Centroid  [-96.729759    32.77614833]
#     #Samples  3
# These are maxClusterIndices None
# ------------------------------------------------------------------------------------
# phone number 7 = 2068627935
#
#
# Examining person:  7
# [[-96.83274489  32.7208804 ]
#  [-96.75941302  32.71247067]
#  [-96.8066212   32.72178311]
#  [-96.709444    32.731611  ]]
#
#   Cluster With Fewest Samples:  3
#
#   Cluster With Most Samples:  0
#     Its Waypoint Time:  0 days 07:45:03.432760
# Cluster Analysis Inertia:  0.0915867122497
# ------------------------------------------
#
#   Cluster  0
#     Centroid  [-96.83274489  32.7208804 ]
#     #Samples  1495
#
#   Cluster  1
#     Centroid  [-96.75941302  32.71247067]
#     #Samples  230
#
#   Cluster  2
#     Centroid  [-96.8066212   32.72178311]
#     #Samples  151
#
#   Cluster  3
#     Centroid  [-96.709444  32.731611]
#     #Samples  22
# These are maxClusterIndices None
# ------------------------------------------------------------------------------------
# phone number 8 = 2894365987
#
#
# Examining person:  8
# [[-96.89192869  32.72173217]
#  [-96.857611    32.741889  ]
#  [-96.875194    32.717667  ]
#  [-96.92004     32.7005    ]]
#
#   Cluster With Fewest Samples:  3
#
#   Cluster With Most Samples:  0
#     Its Waypoint Time:  0 days 10:36:08.165583
# Cluster Analysis Inertia:  0.00750903538954
# ------------------------------------------
#
#   Cluster  0
#     Centroid  [-96.89192869  32.72173217]
#     #Samples  3273
#
#   Cluster  1
#     Centroid  [-96.857611  32.741889]
#     #Samples  292
#
#   Cluster  2
#     Centroid  [-96.875194  32.717667]
#     #Samples  177
#
#   Cluster  3
#     Centroid  [-96.92004  32.7005 ]
#     #Samples  9
# These are maxClusterIndices None
# ------------------------------------------------------------------------------------
# phone number 9 = 8549533077
#
#
# Examining person:  9
# [[-96.805639    32.932     ]
#  [-96.80256326  32.98578914]
#  [-96.80446207  32.90647807]
#  [-96.80231048  32.95816708]]
#
#   Cluster With Fewest Samples:  2
#
#   Cluster With Most Samples:  0
#     Its Waypoint Time:  0 days 07:46:20.918601
# Cluster Analysis Inertia:  0.0550260307133
# ------------------------------------------
#
#   Cluster  0
#     Centroid  [-96.805639  32.932   ]
#     #Samples  99
#
#   Cluster  1
#     Centroid  [-96.80256326  32.98578914]
#     #Samples  2079
#
#   Cluster  2
#     Centroid  [-96.80446207  32.90647807]
#     #Samples  98
#
#   Cluster  3
#     Centroid  [-96.80231048  32.95816708]
#     #Samples  192
# These are maxClusterIndices None
