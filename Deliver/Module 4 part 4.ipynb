# %% [markdown]
# # Assignment 5 - part 2

# %%
# import pandas as pd
# from scipy import misc
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib
# import matplotlib.pyplot as plt
# import numpy as np
# import scipy.io
# import random, math
# from sklearn.decomposition import PCA
# from sklearn import manifold
# import glob

# def Plot2D(T, title, x, y, colour):
#   # This method picks a bunch of random samples (images in your case)
#   # to plot onto the chart:
#   fig = plt.figure()
#   ax = fig.add_subplot(111)
#   ax.set_title(title)
#   ax.set_xlabel('Component: {0}'.format(x))
#   ax.set_ylabel('Component: {0}'.format(y))
#   for i in range(len(T)):
#     ax.scatter(T[:,x],T[:,y], c=colours, marker='.',alpha=0.7)
    
# def Plot3D(T, title, x, y, z, colour):
#   # This method picks a bunch of random samples (images in your case)
#   # to plot onto the chart:
#   fig = plt.figure()
#   ax = fig.add_subplot(111, projection='3d')
#   ax.set_title(title)
#   ax.set_xlabel('Component: {0}'.format(x))
#   ax.set_ylabel('Component: {0}'.format(y))
#   ax.set_zlabel('Component: {0}'.format(z))
#   for i in range(len(T)):
#     ax.scatter(T[:,x],T[:,y], T[:,z], c=colours, marker='.',alpha=0.7)

 
# samples = []
# colours = [] 

# for fname in glob.glob("/home/chris/Documents/python_course/Module4/Datasets/ALOI/32/*"):
#   img = misc.imread(fname)
#   samples.append((img[::2, ::2] / 255.0).reshape(-1))
#   colours.append('b')  
    
# for fname in glob.glob("/home/chris/Documents/python_course/Module4/Datasets/ALOI/32i/*"):
#   img = misc.imread(fname)
#   samples.append((img[::2, ::2] / 255.0).reshape(-1))
#   colours.append('r')  

# df = pd.DataFrame(samples)

# iso = manifold.Isomap(n_neighbors=6, n_components=3)
# iso.fit(df)
# manifold.Isomap(eigen_solver='auto', max_iter=None, n_components=3, n_neighbors=6,neighbors_algorithm='auto', path_method='auto', tol=0)

# T = iso.transform(df)

# i = Plot2D(T, 'Images from Isomap', 0, 1, colour)

# i = Plot3D(T, '3d Images of first 2 components', 0, 1, 2, colour)

# plt.show()
