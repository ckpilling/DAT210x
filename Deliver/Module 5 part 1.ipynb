# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib
# from sklearn.cluster import KMeans

# matplotlib.style.use('ggplot')
# plt.style.use('ggplot')

# def doKMeans(df):
#     # Plot your data with a '.' marker, with 0.3 alpha at the Longitude and Latitude locations
#     fig = plt.figure()
#     ax = fig.add_subplot(111)
#     ax.scatter(df.Longitude, df.Latitude, marker='.', c='black', alpha=0.3)

#     #Filter df on Longitude and Latitude,
#     df2 = df[['Longitude','Latitude']]

#     # Use K-Means to find seven cluster centers.
#     model = KMeans(n_clusters=7)
#     model.fit(df2)
#     KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=7, n_init=10,n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,verbose=0)

#     labels = model.predict(df2)
#     centroids = model.cluster_centers_

#     #Print and plot the centroids...
#     centroids = model.cluster_centers_
#     ax.scatter(centroids[:,0], centroids[:,1], marker='x', c='white', alpha=0.5, linewidths=10, s=169)
#     print centroids
    
# #Load dataset
# df = pd.read_csv('/home/chris/Documents/Projects/DAT210x/Data/Crimes_-_2001_to_present.csv')

# #Drop any ROWs with nans
# df = df.dropna()

# # Coerce 'Date'
# df['Date'] = pd.to_datetime(df['Date'])

# #Print & Plot your data
# doKMeans(df)

# # Index on Date > '2011-01-01'.

# mask = (df['Date'] > '2011-01-01')
# df = df.loc[mask]

# # Print & Plot your data
# doKMeans(df)
# plt.show()
